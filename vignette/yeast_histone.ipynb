# %%
import sragent
import pandas as pd

# %%
projects = ['PRJNA262623', 'PRJNA227448', 'PRJNA140547', 'PRJNA989169',
            'PRJNA954824', 'PRJNA912607', 'PRJNA831793', 'PRJNA783027',
            'PRJNA753826', 'PRJNA737490', 'PRJNA721183', 'PRJNA672715',
            'PRJNA643248', 'PRJNA588479', 'PRJNA559331', 'PRJNA492238',
            'PRJNA487157', 'PRJNA450434', 'PRJNA384583', 'PRJNA320298',
            'PRJNA278334', 'PRJNA274975', 'PRJNA254082', 'PRJNA231240',
            'PRJNA153387']

# %% [markdown]
# The `annotate()` function takes project ids (as string or list) and returns annotated experiment metadata.\
# It works in two steps. \
# 1. a fetch step - pulling metadata from the SRA with the entrez tool kit.
# 2. an annotation step that prompts one of the OpenAI models to summarize and annotate experiment metadata.
#
# By default `annotate()` will perform both of these tasks for every project it's passed.
# But if we want, we can just pull metadata prior to annotation by setting `annotate = False`

# %%
meta = sragent.annotate(projects, model = 'gpt-4o-mini', annotate = False)
# Out:
# Fetching PRJNA262623...
# PRJNA262623 fetch complete...
# Fetching PRJNA227448...
# PRJNA227448 fetch complete...
# Fetching PRJNA140547...
# PRJNA140547 fetch complete...
# Fetching PRJNA989169...
# PRJNA989169 fetch complete...
# Fetching PRJNA954824...
# PRJNA954824 fetch complete...
# Fetching PRJNA912607...
# PRJNA912607 fetch complete...
# Fetching PRJNA831793...
# PRJNA831793 fetch complete...
# Fetching PRJNA783027...
# PRJNA783027 fetch complete...
# Fetching PRJNA753826...
# PRJNA753826 fetch complete...
# Fetching PRJNA737490...
# PRJNA737490 fetch complete...
# Fetching PRJNA721183...
# PRJNA721183 fetch complete...
# Fetching PRJNA672715...
# PRJNA672715 fetch complete...
# Fetching PRJNA643248...
# PRJNA643248 fetch complete...
# Fetching PRJNA588479...
# PRJNA588479 fetch complete...
# Fetching PRJNA559331...
# PRJNA559331 fetch complete...
# Fetching PRJNA492238...
# PRJNA492238 fetch complete...
# Fetching PRJNA487157...
# PRJNA487157 fetch complete...
# Fetching PRJNA450434...
# PRJNA450434 fetch complete...
# Fetching PRJNA384583...
# PRJNA384583 fetch complete...
# Fetching PRJNA320298...
# PRJNA320298 fetch complete...
# Fetching PRJNA278334...
# PRJNA278334 fetch complete...
# Fetching PRJNA274975...
# PRJNA274975 fetch complete...
# Fetching PRJNA254082...
# PRJNA254082 fetch complete...
# Fetching PRJNA231240...
# PRJNA231240 fetch complete...
# Fetching PRJNA153387...
# PRJNA153387 fetch complete...

# %% [markdown]
# `meta` is a pandas dataframe with all of the project ids, experiment ids, abstracts, protocols, experiment titles, and experiment attributes.\
# `annotate()` can also take this dataframe as input, that way we don't have to unnecessarily repeat metadata pulls from the SRA.\
# It also let's us manipulate an subset the metadata before we annotate. \
# For instance, in this vignette we have a total of 25 different projects that include histone PTM ChIP-seq experiments in yeast. \
# But there are non-histone ChIP-seq experiments within these projects as well that we don't care about for now. \
# Let's try to filter down to just experiments with histone targets.\

# %%
ptms = ['k4me','k4me2','k4me3','k27ac']
for x in meta['title']:
    for ptm in ptms:
        if ptm in x.lower():
            print(x)
# Out:
# h3k4me3_0
# h3k4me3_0
# h3k4me3_4
# h3k4me3_4
# h3k4me3_8
# h3k4me3_8
# h3k4me3_15
# h3k4me3_15
# h3k4me3_30
# h3k4me3_30
# h3k4me3_60
# h3k4me3_60
# h3k4me2_0
# h3k4me2_0
# h3k4me2_4
# h3k4me2_4
# h3k4me2_8
# h3k4me2_8
# h3k4me2_15
# h3k4me2_15
# h3k4me2_30
# h3k4me2_30
# h3k4me2_60
# h3k4me2_60
# h3k4me_0
# h3k4me_4
# h3k4me_8
# h3k4me_15
# h3k4me_30
# h3k4me_60
# h3k27ac_0
# h3k27ac_4
# h3k27ac_8
# h3k27ac_15
# h3k27ac_30
# h3k27ac_60
# H3K4me3_ChIP-seq_t16
# H3K4me3_ChIP-seq_t16
# H3K4me3_ChIP-seq_t15
# H3K4me3_ChIP-seq_t15
# H3K4me3_ChIP-seq_t14
# H3K4me3_ChIP-seq_t14
# H3K4me3_ChIP-seq_t13
# H3K4me3_ChIP-seq_t13
# H3K4me3_ChIP-seq_t12
# H3K4me3_ChIP-seq_t12
# H3K4me3_ChIP-seq_t11
# H3K4me3_ChIP-seq_t11
# H3K4me3_ChIP-seq_t10
# H3K4me3_ChIP-seq_t10
# H3K4me3_ChIP-seq_t9
# H3K4me3_ChIP-seq_t9
# H3K4me3_ChIP-seq_t8
# H3K4me3_ChIP-seq_t8
# H3K4me3_ChIP-seq_t7
# H3K4me3_ChIP-seq_t7
# H3K4me3_ChIP-seq_t6
# H3K4me3_ChIP-seq_t6
# H3K4me3_ChIP-seq_t5
# H3K4me3_ChIP-seq_t5
# H3K4me3_ChIP-seq_t4
# H3K4me3_ChIP-seq_t4
# H3K4me3_ChIP-seq_t3
# H3K4me3_ChIP-seq_t3
# H3K4me3_ChIP-seq_t2
# H3K4me3_ChIP-seq_t2
# H3K4me3_ChIP-seq_t1
# H3K4me3_ChIP-seq_t1
# S288E_H3K4me3
# S288E_H3K4me3
# S288A_H3K4me3
# S288A_H3K4me3
# WT_H3K4me3
# WT_H3K4me3
# IAA_H3K4me3_IP_Rep2
# IAA_H3K4me3_IP_Rep2
# IAA_H3K4me3_IP_Rep1
# IAA_H3K4me3_IP_Rep1
# IAA_H3K4me2_IP_Rep2
# IAA_H3K4me2_IP_Rep2
# IAA_H3K4me2_IP_Rep1
# IAA_H3K4me2_IP_Rep1
# DMSO_H3K4me3_IP_Rep2
# DMSO_H3K4me3_IP_Rep2
# DMSO_H3K4me3_IP_Rep1
# DMSO_H3K4me3_IP_Rep1
# DMSO_H3K4me2_IP_Rep2
# DMSO_H3K4me2_IP_Rep2
# DMSO_H3K4me2_IP_Rep1
# DMSO_H3K4me2_IP_Rep1
# H3K27ac, Log Growth Replicate 2
# H3K27ac, Log Growth Replicate 1
# H3K27ac, Exit 240 min Replicate 2
# H3K27ac, Exit 240 min Replicate 1
# H3K27ac, Exit 30 min Replicate 2
# H3K27ac, Exit 30 min Replicate 1
# H3K27ac, Quiescent Replicate 2
# H3K27ac, Quiescent Replicate 1
# YCE1141 H3K4me3 ChIP repeat 2
# YCE1141 H3K4me3 ChIP repeat 2
# YCE1140 H3K4me3 ChIP repeat 2
# YCE1140 H3K4me3 ChIP repeat 2
# YCE281 H3K4me3 ChIP repeat 2
# YCE281 H3K4me3 ChIP repeat 2
# YCE1141 H3K4me3 ChIP repeat 1
# YCE1141 H3K4me3 ChIP repeat 1
# YCE1140 H3K4me3 ChIP repeat 1
# YCE1140 H3K4me3 ChIP repeat 1
# YCE281 H3K4me3 ChIP repeat 1
# YCE281 H3K4me3 ChIP repeat 1
# 20min-H3K4me3-ChIP-WT-2readsFigS7GEO
# 20min-H3K4me3-ChIP-WT-2readsFigS7GEO
# 20min-H3K4me3-ChIPNChAP-WT-2readsFigS7GEO
# 20min-H3K4me3-ChIPNChAP-WT-2readsFigS7GEO
# 25min-H3K4me3-ChIPNChAP-MCM23A-1readsFig6GEO
# 25min-H3K4me3-ChIPNChAP-MCM23A-1readsFig6GEO
# 25min-H3K4me3-ChIP-MCM23A-1readsFig6GEO
# 25min-H3K4me3-ChIP-MCM23A-1readsFig6GEO
# 20min-H3K4me3-ChIPNChAP-MCM23A-1readsFig6GEO
# 20min-H3K4me3-ChIPNChAP-MCM23A-1readsFig6GEO
# 20min-H3K4me3-ChIP-MCM23A-1readsFig6GEO
# 20min-H3K4me3-ChIP-MCM23A-1readsFig6GEO
# 25min-H3K4me3-ChIP-WT-1readsFig5GEO
# 25min-H3K4me3-ChIP-WT-1readsFig5GEO
# 25min-H3K4me3-CHIP-NChAP-WT-1readsFig5GEO
# 25min-H3K4me3-CHIP-NChAP-WT-1readsFig5GEO
# 20min-H3K4me3-ChIP-WT-1readsFig5GEO
# 20min-H3K4me3-ChIP-WT-1readsFig5GEO
# 20min-H3K4me3-ChIPNChAP-WT-1readsFig5GEO
# 20min-H3K4me3-ChIPNChAP-WT-1readsFig5GEO
# 25min-H3K4me3-ChIPNChAP-Mcm23A-2readsFigS7BGEO
# 25min-H3K4me3-ChIPNChAP-Mcm23A-2readsFigS7BGEO
# 25min-ChIP-H3K4me3-Mcm23A-2readsFigS7BGEO
# 25min-ChIP-H3K4me3-Mcm23A-2readsFigS7BGEO
# 20min-H3K4me3-McM23A-2readsFigS7BGEO
# 20min-H3K4me3-McM23A-2readsFigS7BGEO
# 20min-H3K4me3-ChIPNChAP-McM23A-2readsFigS7BGEO
# 20min-H3K4me3-ChIPNChAP-McM23A-2readsFigS7BGEO
# 25min-H3K4me3-ChIP-WT-2readsFigS7GEO
# 25min-H3K4me3-ChIP-WT-2readsFigS7GEO
# 25min-H3K4me3-ChIPNChAP-WT-2techrepreadsFigS7GEO
# 25min-H3K4me3-ChIPNChAP-WT-2techrepreadsFigS7GEO
# 25min-H3K4me3-ChIPNChAP-WT-2readsFigS7GEO
# 25min-H3K4me3-ChIPNChAP-WT-2readsFigS7GEO
# H3K4me3 ChIP-seq, ChIP DNA: Spn1-AID + IAA 2
# H3K4me3 ChIP-seq, ChIP DNA: Spn1-AID + IAA 2
# H3K4me3 ChIP-seq, ChIP DNA: Spn1-AID + IAA 1
# H3K4me3 ChIP-seq, ChIP DNA: Spn1-AID + IAA 1
# H3K4me3 ChIP-seq, ChIP DNA: Spn1-AID + DMSO 2
# H3K4me3 ChIP-seq, ChIP DNA: Spn1-AID + DMSO 2
# H3K4me3 ChIP-seq, ChIP DNA: Spn1-AID + DMSO 1
# H3K4me3 ChIP-seq, ChIP DNA: Spn1-AID + DMSO 1
# H3K4me2_4h_r3
# H3K4me2_4h_r3
# H3K4me2_2h_r3
# H3K4me2_2h_r3
# H3K4me2_4h_r2
# H3K4me2_4h_r2
# H3K4me2_2h_r2
# H3K4me2_2h_r2
# H3K4me2_4h_in_r1
# H3K4me2_4h_in_r1
# H3K4me2_4h_r1
# H3K4me2_4h_r1
# H3K4me2_2h_in_r1
# H3K4me2_2h_in_r1
# H3K4me2_2h_r1
# H3K4me2_2h_r1
# wt_YPD_log_H3K4me3_3_no-spike-in
# wt_YPD_log_H3K4me3_3_no-spike-in
# wt_YPD_log_H3K4me3_2_no-spike-in
# wt_YPD_log_H3K4me3_2_no-spike-in
# wt_YPD_log_H3K4me3_1_no-spike-in
# wt_YPD_log_H3K4me3_1_no-spike-in
# wt_YPD_7.5h_H3K4me3_2_no-spike-in
# wt_YPD_7.5h_H3K4me3_2_no-spike-in
# wt_YPD_7.5h_H3K4me3_1_no-spike-in
# wt_YPD_7.5h_H3K4me3_1_no-spike-in
# wt_YPD_48h_H3K4me3_2_no-spike-in
# wt_YPD_48h_H3K4me3_2_no-spike-in
# wt_YPD_48h_H3K4me3_1_no-spike-in
# wt_YPD_48h_H3K4me3_1_no-spike-in
# wt_YPD_24h_H3K4me3_1_no-spike-in
# wt_YPD_24h_H3K4me3_1_no-spike-in
# wt_YPD_24h_H3K4me3_3_no-spike-in
# wt_YPD_24h_H3K4me3_3_no-spike-in
# wt_YPD_24h_H3K4me3_2_no-spike-in
# wt_YPD_24h_H3K4me3_2_no-spike-in
# H3K4me3/H4_Input_spt6-1004_rep2
# H3K4me3/H4_Input_spt6-1004_rep2
# H3K4me3/H4_Input_spt6-1004_rep1
# H3K4me3/H4_Input_spt6-1004_rep1
# H3K4me3/H4_Input_spt16-197_rep2
# H3K4me3/H4_Input_spt16-197_rep2
# H3K4me3/H4_Input_spt16-197_rep1
# H3K4me3/H4_Input_spt16-197_rep1
# H3K4me3/H4_Input_WT_rep2
# H3K4me3/H4_Input_WT_rep2
# H3K4me3/H4_Input_WT_rep1
# H3K4me3/H4_Input_WT_rep1
# H3K4me3_ChIP-seq_spt6-1004_rep2
# H3K4me3_ChIP-seq_spt6-1004_rep2
# H3K4me3_ChIP-seq_spt6-1004_rep1
# H3K4me3_ChIP-seq_spt6-1004_rep1
# H3K4me3_ChIP-seq_spt16-197_rep2
# H3K4me3_ChIP-seq_spt16-197_rep2
# H3K4me3_ChIP-seq_spt16-197_rep1
# H3K4me3_ChIP-seq_spt16-197_rep1
# H3K4me3_ChIP-seq_WT_rep2
# H3K4me3_ChIP-seq_WT_rep2
# H3K4me3_ChIP-seq_WT_rep1
# H3K4me3_ChIP-seq_WT_rep1
# H3K4me3_WT_2
# H3K4me3_WT_2
# H3K4me3_Disome10_2
# H3K4me3_Disome10_2
# H3K4me3_WT_1
# H3K4me3_WT_1
# H3K4me3_Disome10_1
# H3K4me3_Disome10_1
# Set1G990E H3K4me3 repeat2
# Set1G990E H3K4me3 repeat2
# jhd2Δ H3K4me3 repeat2
# jhd2Δ H3K4me3 repeat2
# wild type H3K4me3 repeat2
# wild type H3K4me3 repeat2
# Set1G990E H3K4me2 repeat2
# Set1G990E H3K4me2 repeat2
# jhd2Δ H3K4me2 repeat2
# jhd2Δ H3K4me2 repeat2
# wild type H3K4me2 repeat2
# wild type H3K4me2 repeat2
# Set1G990E H3K4me1 repeat2
# jhd2Δ H3K4me1 repeat2
# wild type H3K4me1 repeat2
# Set1G990E H3K4me3 repeat1
# Set1G990E H3K4me3 repeat1
# jhd2Δ H3K4me3 repeat1
# jhd2Δ H3K4me3 repeat1
# wild type H3K4me3 repeat1
# wild type H3K4me3 repeat1
# Set1G990E H3K4me2 repeat1
# Set1G990E H3K4me2 repeat1
# jhd2Δ H3K4me2 repeat1
# jhd2Δ H3K4me2 repeat1
# wild type H3K4me2 repeat1
# wild type H3K4me2 repeat1
# Set1G990E H3K4me1 repeat1
# jhd2Δ H3K4me1 repeat1
# wild type H3K4me1 repeat1
# H3K4me3
# H3K4me3
# H3K4me1
# H3K4me3 chIP-seq in H4K44->R mutant yeast, rep #2
# H3K4me3 chIP-seq in H4K44->R mutant yeast, rep #2
# H3K4me3 chIP-seq in H4K44->R mutant yeast, rep #1
# H3K4me3 chIP-seq in H4K44->R mutant yeast, rep #1
# H3K4me3 chIP-seq in WT yeast, rep #2
# H3K4me3 chIP-seq in WT yeast, rep #2
# H3K4me3 chIP-seq in WT yeast, rep #1
# H3K4me3 chIP-seq in WT yeast, rep #1
# H3K4ME3_WT_FM392_Rep_2
# H3K4ME3_WT_FM392_Rep_2
# H3K4ME3_WT_FM392_Rep_1
# H3K4ME3_WT_FM392_Rep_1
# H3K4ME3_leo1_delta_FM392_Rep_2
# H3K4ME3_leo1_delta_FM392_Rep_2
# H3K4ME3_leo1_delta_FM392_Rep_1
# H3K4ME3_leo1_delta_FM392_Rep_1
# H3K4ME3_Full_length_Set1_Rep_2
# H3K4ME3_Full_length_Set1_Rep_2
# H3K4ME3_Full_length_Set1_Rep_1
# H3K4ME3_Full_length_Set1_Rep_1
# H3K4ME3_aa762-1080_Set1_Rep_1
# H3K4ME3_aa762-1080_Set1_Rep_1
# H3K4ME3_chd1_delta_FM392_Rep_2
# H3K4ME3_chd1_delta_FM392_Rep_2
# H3K4ME3_chd1_delta_FM392_Rep_1
# H3K4ME3_chd1_delta_FM392_Rep_1
# H3K4ME3_aa762-1080_Set1_Rep_2
# H3K4ME3_aa762-1080_Set1_Rep_2
# delta_chd1_K4me3
# delta_chd1_K4me3
# wt_FM391_K4me3
# wt_FM391_K4me3

# %%
# !pip install -e ..
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///work/users/m/j/mjn15/sragent
# Requirement already satisfied: pandas in /nas/longleaf/rhel8/apps/anaconda/2021.11/lib/python3.9/site-packages (from sragent==0.1.0) (1.3.4)
# Requirement already satisfied: openai in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from sragent==0.1.0) (1.12.0)
# Requirement already satisfied: biopython in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from sragent==0.1.0) (1.84)
# Requirement already satisfied: pydantic in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from sragent==0.1.0) (2.6.1)
# Requirement already satisfied: numpy in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from biopython->sragent==0.1.0) (1.26.4)
# Requirement already satisfied: sniffio in /nas/longleaf/rhel8/apps/anaconda/2021.11/lib/python3.9/site-packages (from openai->sragent==0.1.0) (1.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from openai->sragent==0.1.0) (4.4.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from openai->sragent==0.1.0) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from openai->sragent==0.1.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from openai->sragent==0.1.0) (0.27.0)
# Requirement already satisfied: tqdm>4 in /nas/longleaf/rhel8/apps/anaconda/2021.11/lib/python3.9/site-packages (from openai->sragent==0.1.0) (4.62.3)
# Requirement already satisfied: idna>=2.8 in /nas/longleaf/rhel8/apps/anaconda/2021.11/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai->sragent==0.1.0) (3.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai->sragent==0.1.0) (1.2.0)
# Requirement already satisfied: certifi in /nas/longleaf/rhel8/apps/anaconda/2021.11/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai->sragent==0.1.0) (2021.10.8)
# Requirement already satisfied: httpcore==1.* in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai->sragent==0.1.0) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->sragent==0.1.0) (0.14.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from pydantic->sragent==0.1.0) (2.16.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /nas/longleaf/home/mjn15/.local/lib/python3.9/site-packages (from pydantic->sragent==0.1.0) (0.6.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /nas/longleaf/rhel8/apps/anaconda/2021.11/lib/python3.9/site-packages (from pandas->sragent==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /nas/longleaf/rhel8/apps/anaconda/2021.11/lib/python3.9/site-packages (from pandas->sragent==0.1.0) (2021.3)
# Requirement already satisfied: six>=1.5 in /nas/longleaf/rhel8/apps/anaconda/2021.11/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->sragent==0.1.0) (1.16.0)
# Installing collected packages: sragent
#   Running setup.py develop for sragent
# Successfully installed sragent
