# %%
import sragent
import pandas as pd

# %% [markdown]
# The `sragent` tool is centered on a single funciton `gather()`. \
# The basic function of `gather()` is to take a Bio Project ID and access the Sequence Read Archive (SRA) to collect metadata on all of the samples within that project.\
# It does this using the `entrez` tools from BioPython and some cluncky XML parsing to extract useful metadata.\
# `gather()` will accept a single ID string or a list of strings for any number of projects.\
# >[!WARNING]
# >`gather()` accesses an external server that is prone to connection problems.\
# > You may encounter connection errors. Usually waiting and rerunning solves this, but you may need to split your request into chuncks.\

# %% [markdown]
# For this demo project I'm going to try to pull and annotate a large number of Yeast Histone PTM ChIP-seq experiments. \
# Below are a list of BioProjecIDs I've already collected that include any experiment profiling a Histone PTM. \

# %%
projects = ['PRJNA262623', 'PRJNA227448', 'PRJNA140547', 'PRJNA989169',
            'PRJNA954824', 'PRJNA912607', 'PRJNA831793', 'PRJNA783027',
            'PRJNA753826', 'PRJNA737490', 'PRJNA721183', 'PRJNA672715',
            'PRJNA643248', 'PRJNA588479', 'PRJNA559331', 'PRJNA492238',
            'PRJNA487157', 'PRJNA450434', 'PRJNA384583', 'PRJNA320298',
            'PRJNA278334', 'PRJNA274975', 'PRJNA254082', 'PRJNA231240'
            'PRJNA153387']

# %% [markdown]
# We can now run `gather()` with this list of IDs. \
# By default, we don't have to provide any other arguments to just get metadata for these projects. \
# This takes ~1m.

# %%
#meta = sragent.gather(projects)
meta = pd.read_csv('sragent_output/metadata.csv')
meta
# Out:
#       project_id                                      project_title  \
# 0    PRJNA262623  High resolution chromatin dynamics during a ye...
# 1    PRJNA262623  High resolution chromatin dynamics during a ye...
# 2    PRJNA262623  High resolution chromatin dynamics during a ye...
# 3    PRJNA262623  High resolution chromatin dynamics during a ye...
# 4    PRJNA262623  High resolution chromatin dynamics during a ye...
# ..           ...                                                ...
# 894  PRJNA231240  Context Dependency of Set1/COMPASS Mediated H3...
# 895  PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
# 896  PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
# 897  PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
# 898  PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
#
#                                               abstract  \
# 0    Covalent histone modifications are highly cons...
# 1    Covalent histone modifications are highly cons...
# 2    Covalent histone modifications are highly cons...
# 3    Covalent histone modifications are highly cons...
# 4    Covalent histone modifications are highly cons...
# ..                                                 ...
# 894  The stimulation of trimethylation of histone H...
# 895  Monoubiquitination of histone H2B on lysine 12...
# 896  Monoubiquitination of histone H2B on lysine 12...
# 897  Monoubiquitination of histone H2B on lysine 12...
# 898  Monoubiquitination of histone H2B on lysine 12...
#
#                                               protocol      run_id  \
# 0    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593257
# 1    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593256
# 2    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593255
# 3    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593254
# 4    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593253
# ..                                                 ...         ...
# 894  We followed the modified ChIP protocol describ...  SRR1048090
# 895                                        NO_PROTOCOL   SRR441518
# 896                                        NO_PROTOCOL   SRR441515
# 897                                        NO_PROTOCOL   SRR441509
# 898                                        NO_PROTOCOL   SRR441506
#
#     experiment_id                          title                  organism  \
# 0       SRX717562                    input2.2_15  Saccharomyces_cerevisiae
# 1       SRX717561                    input1.2_15  Saccharomyces_cerevisiae
# 2       SRX717560                     input2.2_8  Saccharomyces_cerevisiae
# 3       SRX717559                     input3.1_8  Saccharomyces_cerevisiae
# 4       SRX717558                    input1.3_60  Saccharomyces_cerevisiae
# ..            ...                            ...                       ...
# 894     SRX390613  H3K4ME3_aa762-1080_Set1_Rep_2  Saccharomyces_cerevisiae
# 895     SRX127921               delta_chd1_K4me3  Saccharomyces_cerevisiae
# 896     SRX127920              delta_chd1_K79me3  Saccharomyces_cerevisiae
# 897     SRX127918                 wt_FM391_K4me3  Saccharomyces_cerevisiae
# 898     SRX127917                wt_FM391_K79me3  Saccharomyces_cerevisiae
#
#      assay_id                                         attributes
# 0    ChIP-Seq  source_name : BY4741 stress : diamide time : 1...
# 1    ChIP-Seq  source_name : BY4741 stress : diamide time : 1...
# 2    ChIP-Seq  source_name : BY4741 stress : diamide time : 8...
# 3    ChIP-Seq  source_name : BY4741 stress : diamide time : 8...
# 4    ChIP-Seq  source_name : BY4741 stress : diamide time : 6...
# ..        ...                                                ...
# 894  ChIP-Seq  source_name : H3K4ME3_aa762-1080_Set1_Rep_2 ch...
# 895  ChIP-Seq  source_name : delta_Chd1 yeast (FM391,delta Ch...
# 896  ChIP-Seq  source_name : delta_Chd1 yeast (FM391,delta Ch...
# 897  ChIP-Seq  source_name : Wild-type yeast (FM391) genotype...
# 898  ChIP-Seq  source_name : Wild-type yeast (FM391) genotype...
#
# [899 rows x 10 columns]

# %% [markdown]
# `meta` is a pandas dataframe with all of the project ids, experiment ids, abstracts, protocols, experiment titles, and experiment attributes.\
# There are a total of 1,172 experiments here.\
# \
# `annotate()` can also take this dataframe as input, that way we don't have to unnecessarily repeat metadata pulls from the SRA.\
# It also let's us manipulate an subset the metadata before we annotate. \
# For instance, in this vignette we have a total of 25 different projects that include histone PTM ChIP-seq experiments in yeast. \
# But there are non-histone ChIP-seq experiments within these projects as well that we don't care about for now. \
# Let's try to filter down to just experiments with histone targets.\

# %% [markdown]
# First we'll read in a csv with all the histone ptm targets we're interested in, as well as 'H3' and 'input' targets so we don't lose our ChIP-seq controls.\
# We then filter the metadata dataframe with a single string pattern of our desired epitopes and using that as a mask. \
# That drops our total number of experiments to annotate to 899. \

# %%
epitopes = pd.read_csv('epitopes.csv')
eps = '|'.join(epitopes['epitope_id'].tolist())
mask = meta['title'].str.contains(eps, case=False, na=False)
ptm_meta = meta[mask]
ptm_meta
# Out:
#       project_id                                      project_title  \
# 0    PRJNA262623  High resolution chromatin dynamics during a ye...
# 1    PRJNA262623  High resolution chromatin dynamics during a ye...
# 2    PRJNA262623  High resolution chromatin dynamics during a ye...
# 3    PRJNA262623  High resolution chromatin dynamics during a ye...
# 4    PRJNA262623  High resolution chromatin dynamics during a ye...
# ..           ...                                                ...
# 894  PRJNA231240  Context Dependency of Set1/COMPASS Mediated H3...
# 895  PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
# 896  PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
# 897  PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
# 898  PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
#
#                                               abstract  \
# 0    Covalent histone modifications are highly cons...
# 1    Covalent histone modifications are highly cons...
# 2    Covalent histone modifications are highly cons...
# 3    Covalent histone modifications are highly cons...
# 4    Covalent histone modifications are highly cons...
# ..                                                 ...
# 894  The stimulation of trimethylation of histone H...
# 895  Monoubiquitination of histone H2B on lysine 12...
# 896  Monoubiquitination of histone H2B on lysine 12...
# 897  Monoubiquitination of histone H2B on lysine 12...
# 898  Monoubiquitination of histone H2B on lysine 12...
#
#                                               protocol      run_id  \
# 0    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593257
# 1    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593256
# 2    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593255
# 3    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593254
# 4    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593253
# ..                                                 ...         ...
# 894  We followed the modified ChIP protocol describ...  SRR1048090
# 895                                        NO_PROTOCOL   SRR441518
# 896                                        NO_PROTOCOL   SRR441515
# 897                                        NO_PROTOCOL   SRR441509
# 898                                        NO_PROTOCOL   SRR441506
#
#     experiment_id                          title                  organism  \
# 0       SRX717562                    input2.2_15  Saccharomyces_cerevisiae
# 1       SRX717561                    input1.2_15  Saccharomyces_cerevisiae
# 2       SRX717560                     input2.2_8  Saccharomyces_cerevisiae
# 3       SRX717559                     input3.1_8  Saccharomyces_cerevisiae
# 4       SRX717558                    input1.3_60  Saccharomyces_cerevisiae
# ..            ...                            ...                       ...
# 894     SRX390613  H3K4ME3_aa762-1080_Set1_Rep_2  Saccharomyces_cerevisiae
# 895     SRX127921               delta_chd1_K4me3  Saccharomyces_cerevisiae
# 896     SRX127920              delta_chd1_K79me3  Saccharomyces_cerevisiae
# 897     SRX127918                 wt_FM391_K4me3  Saccharomyces_cerevisiae
# 898     SRX127917                wt_FM391_K79me3  Saccharomyces_cerevisiae
#
#      assay_id                                         attributes
# 0    ChIP-Seq  source_name : BY4741 stress : diamide time : 1...
# 1    ChIP-Seq  source_name : BY4741 stress : diamide time : 1...
# 2    ChIP-Seq  source_name : BY4741 stress : diamide time : 8...
# 3    ChIP-Seq  source_name : BY4741 stress : diamide time : 8...
# 4    ChIP-Seq  source_name : BY4741 stress : diamide time : 6...
# ..        ...                                                ...
# 894  ChIP-Seq  source_name : H3K4ME3_aa762-1080_Set1_Rep_2 ch...
# 895  ChIP-Seq  source_name : delta_Chd1 yeast (FM391,delta Ch...
# 896  ChIP-Seq  source_name : delta_Chd1 yeast (FM391,delta Ch...
# 897  ChIP-Seq  source_name : Wild-type yeast (FM391) genotype...
# 898  ChIP-Seq  source_name : Wild-type yeast (FM391) genotype...
#
# [899 rows x 10 columns]

# %% [markdown]
# When we're happy with our subset of experiments we can then rerun `gather()` with the dataframe as input and the `annotate` argument set to `True`.\
# Setting `annotate` to `True` will activate the second part of the tool which is to summarize and annotate the experiments of each project using a LLM (currently any OpenAI model). \
# The LLM annotation involves a two-step process. \
# 1. The model is given the full metadata for a single project. That includes, title, abstract, protocol, and all of the experiment metadata (titles, attributes). \
# It is prompted to provide a summary of that project and answer specific questions about the experiments. These summaries are automatically saved as text files in the `sragent_output/` directory.
# 2. The model is given the summary for a project and the metadata for a *single* experiment, and then prompted to fill out a json schema (using function calling on a pydantic class to enforce structure and type) to define experiment details.\
# These attributes are T/F questions about mutations, deletions, protein depletions, controls, etc. that may or may not be involved in each experiment.

# %% [markdown]
# In order to allow for greater cost control, we need to define which OpenAI model we want to use for each of these LLM steps. \
# In my own testing I have found that the full GPT-4o model is necessary for the best accuracy when generating the json output. \
# But, that the less expensive `gpt-4o-mini` model is sufficient to provide good summarizations. \

# %% [markdown]
# When you run `gather()` it will automatically check if summaries are already present for the BioProject in the `sragent_output/` directory, saving time and money if something goes wrong or we want to rerun the annotation step.\
# And if you have already annotated the metadata, and `sragent_output/annotation_FULL.csv` exists, then `gather()` will skip the LLM annotation and just repeat the generation of sample names, validation check,and control sample matching.\
# That might seem useless, but that makes is much easier to do human-in-the-loop validation. \
# If a particular project is producing consistenly incorrect annotations we can check the summary and make manual corrections that may improve the annotation output.

# %%
#test = ptm_meta[ptm_meta['project_id'] == 'PRJNA262623']
ptm_meta_annotated = sragent.gather(ptm_meta, 
                                    model_summary = 'gpt-4o-mini',
                                    model_annotation = 'gpt-4o-2024-08-06',
                                    annotate = True)
# Out:
# Annotation exists, loading annotation...
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869427 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869426 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869425 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869424 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869423 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869422 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869409 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869408 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869407 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869406 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, True]
# Warning: experiment SRX869405 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869404 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869430 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869429 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869428 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869412 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869411 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX869410 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, True]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944369 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944368 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944367 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944366 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944363 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944362 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944361 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944360 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944357 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944356 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944355 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944354 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944351 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944350 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944349 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944348 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944381 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944380 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944379 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944378 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944375 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944374 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944373 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX3944372 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, True]
# [False, True, False]
# [False, True, False, False]
# [False, True, False, False, False]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# ...
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, True]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, True]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, True]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, True]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, True]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, True]
# [False, False, False, True, False]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, True]
# [False, False, False, True, False]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, True]
# [False, False, False, True, False]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828404 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828403 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828402 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828400 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828399 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828398 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828397 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828410 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828409 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828406 has both gene mutation and gene deletion set to True
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# Warning: experiment SRX20828405 has both gene mutation and gene deletion set to True
# True
# tagging...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...
# setting controls...

# %% [markdown]
# For this large example, using `gpt-4o-2024-08-06` for annotaion (as of 08/14/24), annotation took ~24m, using ~2M tokens at a total cost of ~$6. \
# So for 899 experiments that's less that $0.01 per experiment.

# %% [markdown]
# So what did `gather()` do?
# Let's take a look at the output, which should be saved as `annotation_FULL.csv` in the `sragent_output` directory.

# %% [markdown]
# `ptm_meta_annotated` is a pandas dataframe with the following columns: \
# - `project_id`
# - `experiment_id`
# - `exp_title` - title of the experiment as listed in the SRA metadata
# (the following columns are generated from the LLM response)
# - `gene_mutatation` - True or False: does this experiment test a gene mutation?
# - `gene_deletion` - True or False: does this experiment test a gene deletion?
# - `protein_depletion` - True or False: does this experiment test a protein depletion?
# - `stress_condition` - True or False: does this experiment test a stress condition?
# - `time_series` - True or False: is this experiment specify a specific time point or growth stage?
# - `chip_input` - True or False: is this an input experiment?
# - `antibody_control` - True or False: is this an antibody control? ie. a non-specific antibody
# - `chip_target` - protein targeted in the experiment
# - `mutatation` - specific mutation if present
# - `deletion` - specific deletion if present
# - `depletion` - protein depleted if present
# - `stress` - stress condition if present
# - `time_point`
# (the following are determined based on the classifications from the LLM above)
# - `warnning` - True or False: flags a logical disagreement between the LLM classifications. Useful to catch mistakes and guide human review
# - `sample` - a simple sample name or tag that merges experiment attributes like genotype, time, target.
# - `perturbation` - one of ['None','gene_mutation','gene_deletion','protein_depletion','stress_condition']
# - `control` - the `sample` name of the control (input or other) experiment that matches target for that project

# %% [markdown]
# Let's examine how well the model did at classifying and annotating these experiments.\
# How many experiments were flagged for review?

# %%
#ptm_meta_annotated
warnings = ptm_meta_annotated[ptm_meta_annotated['warning']]
warnings
# Out:
#                 experiment_id                                exp_title  \
# project_id
# PRJNA274975 233     SRX869427                Rph1- Old (S3O, Exp 2) H3
#             234     SRX869426                Rph1- Old (S2O, Exp 2) H3
#             235     SRX869425              Rph1- Young (S2Y, Exp 2) H3
#             236     SRX869424          Rph1- Old (S3O, Exp 2) H3K36me3
#             237     SRX869423          Rph1- Old (S2O, Exp 2) H3K36me3
# ...                       ...                                      ...
# PRJNA989169 639   SRX20828397  H3K9me2; TetR-SET; Suv39x; ChIP-seq (B)
#             642   SRX20828410                    input DNA; AY4345 (B)
#             643   SRX20828409                    input DNA; AY4345 (A)
#             646   SRX20828406                    input DNA; AY2896 (B)
#             647   SRX20828405                    input DNA; AY2896 (A)
#
#                  gene_mutation  gene_deletion  protein_depletion  \
# project_id
# PRJNA274975 233           True           True              False
#             234           True           True              False
#             235           True           True              False
#             236           True           True              False
#             237           True           True              False
# ...                        ...            ...                ...
# PRJNA989169 639           True           True              False
#             642           True           True              False
#             643           True           True              False
#             646           True           True              False
#             647           True           True              False
#
#                  stress_condition  time_series  chip_input  antibody_control  \
# project_id
# PRJNA274975 233             False        False       False             False
#             234             False        False       False             False
#             235             False        False       False             False
#             236             False         True       False             False
#             237             False        False       False             False
# ...                           ...          ...         ...               ...
# PRJNA989169 639             False        False       False             False
#             642             False        False        True             False
#             643             False        False        True             False
#             646             False        False        True             False
#             647             False        False        True             False
#
#                 chip_target  ... depletion stress    time_point   project_id  \
# project_id                   ...
# PRJNA274975 233          H3  ...                                 PRJNA274975
#             234          H3  ...                                 PRJNA274975
#             235          H3  ...                                 PRJNA274975
#             236    H3K36me3  ...                   Old_S3O_Exp2  PRJNA274975
#             237    H3K36me3  ...                                 PRJNA274975
# ...                     ...  ...       ...    ...           ...          ...
# PRJNA989169 639     H3K9me2  ...                                 PRJNA989169
#             642              ...                                 PRJNA989169
#             643              ...                                 PRJNA989169
#             646              ...                                 PRJNA989169
#             647              ...                                 PRJNA989169
#
#                 model_summary   model_annotation warning  \
# project_id
# PRJNA274975 233   gpt-4o-mini  gpt-4o-2024-08-06    True
#             234   gpt-4o-mini  gpt-4o-2024-08-06    True
#             235   gpt-4o-mini  gpt-4o-2024-08-06    True
#             236   gpt-4o-mini  gpt-4o-2024-08-06    True
#             237   gpt-4o-mini  gpt-4o-2024-08-06    True
# ...                       ...                ...     ...
# PRJNA989169 639   gpt-4o-mini  gpt-4o-2024-08-06    True
#             642   gpt-4o-mini  gpt-4o-2024-08-06    True
#             643   gpt-4o-mini  gpt-4o-2024-08-06    True
#             646   gpt-4o-mini  gpt-4o-2024-08-06    True
#             647   gpt-4o-mini  gpt-4o-2024-08-06    True
#
#                                                         sample   perturbation  \
# project_id
# PRJNA274975 233                         H3-Rph1--gene_mutation  gene_mutation
#             234                         H3-Rph1--gene_mutation  gene_mutation
#             235                         H3-Rph1--gene_mutation  gene_mutation
#             236      H3K36me3-Rph1--gene_mutation-Old_S3O_Exp2  gene_mutation
#             237                   H3K36me3-Rph1--gene_mutation  gene_mutation
# ...                                                        ...            ...
# PRJNA989169 639                 H3K9me2-TetR-SET-gene_mutation  gene_mutation
#             642  Input-hflD::URA3Kl-tetO10X-ADE2-gene_mutation  gene_mutation
#             643   Input-hflD-URA3Kl-tetO10X-ADE2-gene_mutation  gene_mutation
#             646          Input-hmrD-tetO10X-ADE2-gene_mutation  gene_mutation
#             647          Input-hmrD-tetO10X-ADE2-gene_mutation  gene_mutation
#
#                                    control
# project_id
# PRJNA274975 233  Input-Rph1--gene_mutation
#             234  Input-Rph1--gene_mutation
#             235  Input-Rph1--gene_mutation
#             236                       None
#             237  Input-Rph1--gene_mutation
# ...                                    ...
# PRJNA989169 639                       None
#             642
#             643
#             646
#             647
#
# [65 rows x 22 columns]

# %% [markdown]
# 65 of our 899 experiments have 'warnings' meaning there is some logical inconsistency between some of the classifications.\
# eg. a sample is marked as having a gene_mutation but no mutation is listed or vice versa.

# %% [markdown]
# Looking at one project (PRJNA274975) we see that these experiments are being classified as having both gene deletions and mutations, and we're getting some ugly sample names as a result.\
# The time series annotation is also inconsistent, and most of the experiments aren't being correctly annotated as 'young' or 'old' which seems to be an important designator in this project.

# %%
warnings[warnings['project_id'] == 'PRJNA274975']
# Out:
#                 experiment_id                          exp_title  \
# project_id
# PRJNA274975 233     SRX869427          Rph1- Old (S3O, Exp 2) H3
#             234     SRX869426          Rph1- Old (S2O, Exp 2) H3
#             235     SRX869425        Rph1- Young (S2Y, Exp 2) H3
#             236     SRX869424    Rph1- Old (S3O, Exp 2) H3K36me3
#             237     SRX869423    Rph1- Old (S2O, Exp 2) H3K36me3
#             238     SRX869422  Rph1- Young (S2Y, Exp 2) H3K36me3
#             245     SRX869409          Rph1- Old (S3O, Exp 1) H3
#             246     SRX869408          Rph1- Old (S2O, Exp 1) H3
#             247     SRX869407        Rph1- Young (S2Y, Exp 1) H3
#             248     SRX869406    Rph1- Old (S3O, Exp 1) H3K36me3
#             249     SRX869405    Rph1- Old (S2O, Exp 1) H3K36me3
#             250     SRX869404  Rph1- Young (S2Y, Exp 1) H3K36me3
#             257     SRX869430       Rph1- Old (S3O, Exp 2) Input
#             258     SRX869429       Rph1- Old (S2O, Exp 2) Input
#             259     SRX869428     Rph1- Young (S2Y, Exp 2) Input
#             263     SRX869412       Rph1- Old (S3O, Exp 1) Input
#             264     SRX869411       Rph1- Old (S2O, Exp 1) Input
#             265     SRX869410     Rph1- Young (S2Y, Exp 1) Input
#
#                  gene_mutation  gene_deletion  protein_depletion  \
# project_id
# PRJNA274975 233           True           True              False
#             234           True           True              False
#             235           True           True              False
#             236           True           True              False
#             237           True           True              False
#             238           True           True              False
#             245           True           True              False
#             246           True           True              False
#             247           True           True              False
#             248           True           True              False
#             249           True           True              False
#             250           True           True              False
#             257           True           True              False
#             258           True           True              False
#             259           True           True              False
#             263           True           True              False
#             264           True           True              False
#             265           True           True              False
#
#                  stress_condition  time_series  chip_input  antibody_control  \
# project_id
# PRJNA274975 233             False        False       False             False
#             234             False        False       False             False
#             235             False        False       False             False
#             236             False         True       False             False
#             237             False        False       False             False
#             238             False        False       False             False
#             245             False        False       False             False
#             246             False        False       False             False
#             247             False        False       False             False
#             248             False        False       False             False
#             249             False        False       False             False
#             250             False        False       False             False
#             257             False        False        True              True
#             258             False        False        True              True
#             259             False        False        True              True
#             263             False        False        True              True
#             264             False        False        True              True
#             265             False        False        True              True
#
#                 chip_target  ... depletion stress    time_point   project_id  \
# project_id                   ...
# PRJNA274975 233          H3  ...                                 PRJNA274975
#             234          H3  ...                                 PRJNA274975
#             235          H3  ...                                 PRJNA274975
#             236    H3K36me3  ...                   Old_S3O_Exp2  PRJNA274975
#             237    H3K36me3  ...                                 PRJNA274975
#             238    H3K36me3  ...                                 PRJNA274975
#             245          H3  ...                                 PRJNA274975
#             246          H3  ...                                 PRJNA274975
#             247          H3  ...                                 PRJNA274975
#             248    H3K36me3  ...                                 PRJNA274975
#             249    H3K36me3  ...                            Old  PRJNA274975
#             250    H3K36me3  ...                                 PRJNA274975
#             257              ...                                 PRJNA274975
#             258              ...                                 PRJNA274975
#             259              ...                                 PRJNA274975
#             263              ...                                 PRJNA274975
#             264              ...                                 PRJNA274975
#             265              ...                                 PRJNA274975
#
#                 model_summary   model_annotation warning  \
# project_id
# PRJNA274975 233   gpt-4o-mini  gpt-4o-2024-08-06    True
#             234   gpt-4o-mini  gpt-4o-2024-08-06    True
#             235   gpt-4o-mini  gpt-4o-2024-08-06    True
#             236   gpt-4o-mini  gpt-4o-2024-08-06    True
#             237   gpt-4o-mini  gpt-4o-2024-08-06    True
#             238   gpt-4o-mini  gpt-4o-2024-08-06    True
#             245   gpt-4o-mini  gpt-4o-2024-08-06    True
#             246   gpt-4o-mini  gpt-4o-2024-08-06    True
#             247   gpt-4o-mini  gpt-4o-2024-08-06    True
#             248   gpt-4o-mini  gpt-4o-2024-08-06    True
#             249   gpt-4o-mini  gpt-4o-2024-08-06    True
#             250   gpt-4o-mini  gpt-4o-2024-08-06    True
#             257   gpt-4o-mini  gpt-4o-2024-08-06    True
#             258   gpt-4o-mini  gpt-4o-2024-08-06    True
#             259   gpt-4o-mini  gpt-4o-2024-08-06    True
#             263   gpt-4o-mini  gpt-4o-2024-08-06    True
#             264   gpt-4o-mini  gpt-4o-2024-08-06    True
#             265   gpt-4o-mini  gpt-4o-2024-08-06    True
#
#                                                     sample   perturbation  \
# project_id
# PRJNA274975 233                     H3-Rph1--gene_mutation  gene_mutation
#             234                     H3-Rph1--gene_mutation  gene_mutation
#             235                     H3-Rph1--gene_mutation  gene_mutation
#             236  H3K36me3-Rph1--gene_mutation-Old_S3O_Exp2  gene_mutation
#             237               H3K36me3-Rph1--gene_mutation  gene_mutation
#             238               H3K36me3-Rph1--gene_mutation  gene_mutation
#             245                     H3-Rph1--gene_mutation  gene_mutation
#             246                     H3-Rph1--gene_mutation  gene_mutation
#             247                     H3-Rph1--gene_mutation  gene_mutation
#             248               H3K36me3-Rph1--gene_mutation  gene_mutation
#             249               H3K36me3-Rph1--gene_mutation  gene_mutation
#             250               H3K36me3-Rph1--gene_mutation  gene_mutation
#             257                  Input-Rph1--gene_mutation  gene_mutation
#             258                  Input-Rph1--gene_mutation  gene_mutation
#             259                  Input-Rph1--gene_mutation  gene_mutation
#             263                  Input-Rph1--gene_mutation  gene_mutation
#             264                  Input-Rph1--gene_mutation  gene_mutation
#             265                  Input-Rph1--gene_mutation  gene_mutation
#
#                                    control
# project_id
# PRJNA274975 233  Input-Rph1--gene_mutation
#             234  Input-Rph1--gene_mutation
#             235  Input-Rph1--gene_mutation
#             236                       None
#             237  Input-Rph1--gene_mutation
#             238  Input-Rph1--gene_mutation
#             245  Input-Rph1--gene_mutation
#             246  Input-Rph1--gene_mutation
#             247  Input-Rph1--gene_mutation
#             248  Input-Rph1--gene_mutation
#             249  Input-Rph1--gene_mutation
#             250  Input-Rph1--gene_mutation
#             257
#             258
#             259
#             263
#             264
#             265
#
# [18 rows x 22 columns]

# %% [markdown]
# Let's take a look at the summary for this project.

# %%
with open('sragent_output/PRJNA274975_summary.txt', 'r') as f:
    print(f.read())
# Out:
# ### Project Summary
# The main goal of the project (PRJNA274975) is to investigate the role of H3K36 methylation in promoting longevity in yeast (S. cerevisiae) by enhancing transcriptional fidelity. The project tests the hypothesis that loss of sustained H3K36 methylation leads to increased cryptic transcription in aging cells, which is associated with a shorter lifespan. The study examines the effects of the deletion of the K36me2/3 demethylase Rph1 on H3K36 methylation levels and lifespan extension.
#
# ### Experimental Conditions
# The experiments are conducted under different conditions based on the age of the yeast cells (young vs. old) and the genetic background (wild-type (WT) vs. Rph1 mutant). The project includes three sorts of yeast: S2Y (young), S2O (old), and S3O (old), with two replicates (F1 and F2).
#
# ### Analysis of Metadata
#
# 1. **Key Words Indicating Gene Mutations:**
#    - There are no specific keywords indicating a gene mutation in the project.
#
# 2. **Key Words Indicating Gene Deletions:**
#    - "Rph1-" indicates a deletion of the Rph1 gene, as it suggests a complete loss of function of this gene.
#
# 3. **Key Words Indicating Protein Depletions:**
#    - There are no specific keywords indicating protein depletion in the metadata provided. The project focuses on genetic mutations rather than induced protein depletion.
#
# 4. **Key Words Indicating Chemical Treatments or Stress Conditions:**
#    - The metadata does not explicitly mention any chemical treatments or stress conditions. The focus is primarily on genetic backgrounds and age-related changes.
#
# 5. **Key Words Indicating Experiments Separated Over Time:**
#    - The terms "Exp 1" and "Exp 2" in the experiment titles indicate different experimental replicates, but there are no specific keywords indicating time points or stages of development/growth.
#
# 6. **Key Words Indicating ChIP Input Control:**
#    - The term "Input" in the experiment titles indicates that the experiment is a ChIP Input control.
#
# 7. **Key Words Indicating Non-Specific Antibody Control:**
#    - The attribute "antibody : None" indicates that the experiment is a non-specific antibody control.
#
# 8. **Key Words Indicating ChIP-seq Protein Targets:**
#    - The protein targets are indicated by the terms "H3K36me3" (for the histone modification) and "H3" (for the histone protein). The relevant protein targets are:
#      - H3K36me3 (Brno notation for histone modification)
#      - H3 (UCSC Gene Symbol for histone protein)
#    - For Input experiments, the protein target is "None."
#
# 9. **Key Words Indicating Experimental Replicates:**
#    - The terms "Exp 1" and "Exp 2" in the experiment titles indicate that there are experimental replicates.
#
# 10. **Key Words Indicating Small Molecules Used:**
#     - The metadata does not mention any small molecules being used to induce stress or protein depletion in specific experiments.
#
# ### Conclusion
# The project focuses on the genetic manipulation of the Rph1 gene to study its effects on H3K36 methylation and transcriptional fidelity in aging yeast cells. The experiments are well-structured with clear distinctions between different genetic backgrounds, age groups, and controls, although there is no indication of chemical treatments or small molecules used in the experiments.

# %% [markdown]
# It looks like the summary got a couple of things wrong.
# >[!QUOTE]
# >1. **Key Words Indicating Gene Mutations:**
# >   - "Rph1-" indicates a mutation in the Rph1 gene. This is the only relevant mutation in the context of the project.
# >2. **Key Words Indicating Gene Deletions:**
# >   - "Rph1-" also indicates a deletion of the Rph1 gene, as it suggests a complete loss of function of this gene.
# >5. **Key Words Indicating Experiments Separated Over Time:**
# >   - The terms "Exp 1" and "Exp 2" in the experiment titles indicate different experimental replicates, but there are no specific keywords indicating time points or stages of development/growth.
#
# Most likely we don't want experiments involving 'Rph1-' to be classified as both deletions and mutations.\
# Without examining the project details further, it seems safe to assume that 'Rph1-' is supposed to indicate a deletion of Rph1.

# %% [markdown]
# Let's make the following changes:
# >[!QUOTE]
# >1. **Key Words Indicating Gene Mutations:**
# >   - There are no specific keywords indicating a gene mutation in the project.
# >2. **Key Words Indicating Gene Deletions:**
# >   - "Rph1-" indicates a deletion of the Rph1 gene, as it suggests a complete loss of function of this gene.
# >5. **Key Words Indicating Experiments Separated Over Time:**
# >   - The terms "Young" and "Old" in the experiment titles indicate different time points
#
# And then save the new summary as `PRJNA274975_summary-corrected.txt` \
# This is mostly for the purposes of this demonstration, so we don't lose the incorrect summary.\
# I've added an argument to `gather()` to prefrentially load any summary files appended with `-corrected.txt`, just specify `use_corrected = True`.\

# %% [markdown]
# Now, we don't want to reannotate all projects. Just PRJNA27975 that was giving us problems.\
# So we can pass in the subset of that dataframe for just that project and reannotate.

# %%
ptm_meta_annotated_corrected = sragent.gather(ptm_meta[ptm_meta['project_id'] == 'PRJNA274975'], 
                                    model_summary = 'gpt-4o-mini',
                                    model_annotation = 'gpt-4o-2024-08-06',
                                    use_corrected = True,
                                    annotate = True)
# Out:
# Corrected summary exists, loading PRJNA274975 summary...
# annotating experiment 827    SRX869430
# Name: experiment_id, dtype: object...
# annotating experiment 828    SRX869429
# Name: experiment_id, dtype: object...
# annotating experiment 829    SRX869428
# Name: experiment_id, dtype: object...
# annotating experiment 830    SRX869427
# Name: experiment_id, dtype: object...
# annotating experiment 831    SRX869426
# Name: experiment_id, dtype: object...
# annotating experiment 832    SRX869425
# Name: experiment_id, dtype: object...
# annotating experiment 833    SRX869424
# Name: experiment_id, dtype: object...
# annotating experiment 834    SRX869423
# Name: experiment_id, dtype: object...
# annotating experiment 835    SRX869422
# Name: experiment_id, dtype: object...
# annotating experiment 836    SRX869421
# Name: experiment_id, dtype: object...
# annotating experiment 837    SRX869420
# Name: experiment_id, dtype: object...
# annotating experiment 838    SRX869419
# Name: experiment_id, dtype: object...
# annotating experiment 839    SRX869418
# Name: experiment_id, dtype: object...
# annotating experiment 840    SRX869417
# Name: experiment_id, dtype: object...
# annotating experiment 841    SRX869416
# Name: experiment_id, dtype: object...
# annotating experiment 842    SRX869415
# Name: experiment_id, dtype: object...
# annotating experiment 843    SRX869414
# Name: experiment_id, dtype: object...
# annotating experiment 844    SRX869413
# Name: experiment_id, dtype: object...
# annotating experiment 845    SRX869412
# Name: experiment_id, dtype: object...
# annotating experiment 846    SRX869411
# Name: experiment_id, dtype: object...
# annotating experiment 847    SRX869410
# Name: experiment_id, dtype: object...
# annotating experiment 848    SRX869409
# Name: experiment_id, dtype: object...
# annotating experiment 849    SRX869408
# Name: experiment_id, dtype: object...
# annotating experiment 850    SRX869407
# Name: experiment_id, dtype: object...
# annotating experiment 851    SRX869406
# Name: experiment_id, dtype: object...
# annotating experiment 852    SRX869405
# Name: experiment_id, dtype: object...
# annotating experiment 853    SRX869404
# Name: experiment_id, dtype: object...
# annotating experiment 854    SRX869403
# Name: experiment_id, dtype: object...
# annotating experiment 855    SRX869402
# Name: experiment_id, dtype: object...
# annotating experiment 856    SRX869401
# Name: experiment_id, dtype: object...
# annotating experiment 857    SRX869400
# Name: experiment_id, dtype: object...
# annotating experiment 858    SRX869399
# Name: experiment_id, dtype: object...
# annotating experiment 859    SRX869398
# Name: experiment_id, dtype: object...
# annotating experiment 860    SRX869397
# Name: experiment_id, dtype: object...
# annotating experiment 861    SRX869396
# Name: experiment_id, dtype: object...
# annotating experiment 862    SRX869395
# Name: experiment_id, dtype: object...
# project PRJNA274975 done!
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, True]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, True]
# True
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# [False]
# [False, False]
# [False, False, False]
# [False, False, False, False]
# [False, False, False, False, False]
# False
# tagging...
# setting controls...
