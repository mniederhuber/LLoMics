# %%
import sragent
import pandas as pd

# %% [markdown]
# The `sragent` tool is centered on a single funciton `gather()`. \
# The basic function of `gather()` is to take a Bio Project ID and access the Sequence Read Archive (SRA) to collect metadata on all of the samples within that project.\
# It does this using the `entrez` tools from BioPython and some cluncky XML parsing to extract useful metadata.\
# `gather()` will accept a single ID string or a list of strings for any number of projects.\
# >[!WARNING]
# >`gather()` accesses an external server that is prone to connection problems.\
# > You may encounter connection errors. Usually waiting and rerunning solves this, but you may need to split your request into chuncks.\

# %% [markdown]
# For this demo project I'm going to try to pull and annotate a large number of Yeast Histone PTM ChIP-seq experiments. \
# Below are a list of BioProjecIDs I've already collected that include any experiment profiling a Histone PTM. \

# %%
projects = ['PRJNA262623', 'PRJNA227448', 'PRJNA140547', 'PRJNA989169',
            'PRJNA954824', 'PRJNA912607', 'PRJNA831793', 'PRJNA783027',
            'PRJNA753826', 'PRJNA737490', 'PRJNA721183', 'PRJNA672715',
            'PRJNA643248', 'PRJNA588479', 'PRJNA559331', 'PRJNA492238',
            'PRJNA487157', 'PRJNA450434', 'PRJNA384583', 'PRJNA320298',
            'PRJNA278334', 'PRJNA274975', 'PRJNA254082', 'PRJNA231240',
            'PRJNA153387']

# %% [markdown]
# We can now run `gather()` with this list of IDs. \
# By default, we don't have to provide any other arguments to just get metadata for these projects.

# %%
meta = sragent.gather(projects)
#meta = pd.read_csv('sragent_output/metadata.csv')
meta
# Out:
# Fetching PRJNA262623...
# PRJNA262623 fetch complete...
# Fetching PRJNA227448...
# PRJNA227448 fetch complete...
# Fetching PRJNA140547...
# PRJNA140547 fetch complete...
# Fetching PRJNA989169...
# PRJNA989169 fetch complete...
# Fetching PRJNA954824...
# PRJNA954824 fetch complete...
# Fetching PRJNA912607...
# PRJNA912607 fetch complete...
# Fetching PRJNA831793...
# PRJNA831793 fetch complete...
# Fetching PRJNA783027...
# PRJNA783027 fetch complete...
# Fetching PRJNA753826...
# PRJNA753826 fetch complete...
# Fetching PRJNA737490...
# PRJNA737490 fetch complete...
# Fetching PRJNA721183...
# PRJNA721183 fetch complete...
# Fetching PRJNA672715...
# PRJNA672715 fetch complete...
# Fetching PRJNA643248...
# PRJNA643248 fetch complete...
# Fetching PRJNA588479...
# PRJNA588479 fetch complete...
# Fetching PRJNA559331...
# PRJNA559331 fetch complete...
# Fetching PRJNA492238...
# PRJNA492238 fetch complete...
# Fetching PRJNA487157...
# PRJNA487157 fetch complete...
# Fetching PRJNA450434...
# PRJNA450434 fetch complete...
# Fetching PRJNA384583...
# PRJNA384583 fetch complete...
# Fetching PRJNA320298...
# PRJNA320298 fetch complete...
# Fetching PRJNA278334...
# PRJNA278334 fetch complete...
# Fetching PRJNA274975...
# PRJNA274975 fetch complete...
# Fetching PRJNA254082...
# PRJNA254082 fetch complete...
# Fetching PRJNA231240...
# PRJNA231240 fetch complete...
# Fetching PRJNA153387...
# PRJNA153387 fetch complete...
#      project_id                                      project_title  \
# 0   PRJNA262623  High resolution chromatin dynamics during a ye...
# 1   PRJNA262623  High resolution chromatin dynamics during a ye...
# 2   PRJNA262623  High resolution chromatin dynamics during a ye...
# 3   PRJNA262623  High resolution chromatin dynamics during a ye...
# 4   PRJNA262623  High resolution chromatin dynamics during a ye...
# ..          ...                                                ...
# 1   PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
# 2   PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
# 3   PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
# 4   PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
# 5   PRJNA153387  Co-dependency of H2B monoubiquitination and nu...
#
#                                              abstract  \
# 0   Covalent histone modifications are highly cons...
# 1   Covalent histone modifications are highly cons...
# 2   Covalent histone modifications are highly cons...
# 3   Covalent histone modifications are highly cons...
# 4   Covalent histone modifications are highly cons...
# ..                                                ...
# 1   Monoubiquitination of histone H2B on lysine 12...
# 2   Monoubiquitination of histone H2B on lysine 12...
# 3   Monoubiquitination of histone H2B on lysine 12...
# 4   Monoubiquitination of histone H2B on lysine 12...
# 5   Monoubiquitination of histone H2B on lysine 12...
#
#                                              protocol      run_id  \
# 0   Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593257
# 1   Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593256
# 2   Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593255
# 3   Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593254
# 4   Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593253
# ..                                                ...         ...
# 1                                         NO_PROTOCOL   SRR441515
# 2                                         NO_PROTOCOL   SRR441512
# 3                                         NO_PROTOCOL   SRR441509
# 4                                         NO_PROTOCOL   SRR441506
# 5                                         NO_PROTOCOL   SRR441503
#
#    experiment_id              title                  organism  assay_id  \
# 0      SRX717562        input2.2_15  Saccharomyces_cerevisiae  ChIP-Seq
# 1      SRX717561        input1.2_15  Saccharomyces_cerevisiae  ChIP-Seq
# 2      SRX717560         input2.2_8  Saccharomyces_cerevisiae  ChIP-Seq
# 3      SRX717559         input3.1_8  Saccharomyces_cerevisiae  ChIP-Seq
# 4      SRX717558        input1.3_60  Saccharomyces_cerevisiae  ChIP-Seq
# ..           ...                ...                       ...       ...
# 1      SRX127920  delta_chd1_K79me3  Saccharomyces_cerevisiae  ChIP-Seq
# 2      SRX127919     delta_chd1_wce  Saccharomyces_cerevisiae  ChIP-Seq
# 3      SRX127918     wt_FM391_K4me3  Saccharomyces_cerevisiae  ChIP-Seq
# 4      SRX127917    wt_FM391_K79me3  Saccharomyces_cerevisiae  ChIP-Seq
# 5      SRX127916       wt_FM391_wce  Saccharomyces_cerevisiae  ChIP-Seq
#
#                                            attributes
# 0   source_name : BY4741 stress : diamide time : 1...
# 1   source_name : BY4741 stress : diamide time : 1...
# 2   source_name : BY4741 stress : diamide time : 8...
# 3   source_name : BY4741 stress : diamide time : 8...
# 4   source_name : BY4741 stress : diamide time : 6...
# ..                                                ...
# 1   source_name : delta_Chd1 yeast (FM391,delta Ch...
# 2   source_name : delta_Chd1 yeast (FM391,delta Ch...
# 3   source_name : Wild-type yeast (FM391) genotype...
# 4   source_name : Wild-type yeast (FM391) genotype...
# 5   source_name : Wild-type yeast (FM391) genotype...
#
# [1172 rows x 10 columns]

# %% [markdown]
# `meta` is a pandas dataframe with all of the project ids, experiment ids, abstracts, protocols, experiment titles, and experiment attributes.\
# There are a total of 1,172 experiments here.\
# \
# `annotate()` can also take this dataframe as input, that way we don't have to unnecessarily repeat metadata pulls from the SRA.\
# It also let's us manipulate an subset the metadata before we annotate. \
# For instance, in this vignette we have a total of 25 different projects that include histone PTM ChIP-seq experiments in yeast. \
# But there are non-histone ChIP-seq experiments within these projects as well that we don't care about for now. \
# Let's try to filter down to just experiments with histone targets.\

# %% [markdown]
# First we'll read in a csv with all the histone ptm targets we're interested in, as well as 'H3' and 'input' targets so we don't lose our ChIP-seq controls.\
# We then filter the metadata dataframe with a single string pattern of our desired epitopes and using that as a mask. \
# That drops our total number of experiments to annotate to 899. \

# %%
epitopes = pd.read_csv('epitopes.csv')
eps = '|'.join(epitopes['epitope_id'].tolist())
mask = meta['title'].str.contains(eps, case=False, na=False)
ptm_meta = meta[mask]
ptm_meta
# Out:
#       project_id                                      project_title  \
# 0    PRJNA262623  High resolution chromatin dynamics during a ye...
# 1    PRJNA262623  High resolution chromatin dynamics during a ye...
# 2    PRJNA262623  High resolution chromatin dynamics during a ye...
# 3    PRJNA262623  High resolution chromatin dynamics during a ye...
# 4    PRJNA262623  High resolution chromatin dynamics during a ye...
# ..           ...                                                ...
# 190  PRJNA262623  High resolution chromatin dynamics during a ye...
# 191  PRJNA262623  High resolution chromatin dynamics during a ye...
# 192  PRJNA262623  High resolution chromatin dynamics during a ye...
# 193  PRJNA262623  High resolution chromatin dynamics during a ye...
# 194  PRJNA262623  High resolution chromatin dynamics during a ye...
#
#                                               abstract  \
# 0    Covalent histone modifications are highly cons...
# 1    Covalent histone modifications are highly cons...
# 2    Covalent histone modifications are highly cons...
# 3    Covalent histone modifications are highly cons...
# 4    Covalent histone modifications are highly cons...
# ..                                                 ...
# 190  Covalent histone modifications are highly cons...
# 191  Covalent histone modifications are highly cons...
# 192  Covalent histone modifications are highly cons...
# 193  Covalent histone modifications are highly cons...
# 194  Covalent histone modifications are highly cons...
#
#                                               protocol      run_id  \
# 0    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593257
# 1    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593256
# 2    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593255
# 3    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593254
# 4    Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593253
# ..                                                 ...         ...
# 190  Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593061
# 191  Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593060
# 192  Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593059
# 193  Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593058
# 194  Formaldehyde was quenched by 125mM glycine. Ce...  SRR1593057
#
#     experiment_id        title                  organism  assay_id  \
# 0       SRX717562  input2.2_15  Saccharomyces_cerevisiae  ChIP-Seq
# 1       SRX717561  input1.2_15  Saccharomyces_cerevisiae  ChIP-Seq
# 2       SRX717560   input2.2_8  Saccharomyces_cerevisiae  ChIP-Seq
# 3       SRX717559   input3.1_8  Saccharomyces_cerevisiae  ChIP-Seq
# 4       SRX717558  input1.3_60  Saccharomyces_cerevisiae  ChIP-Seq
# ..            ...          ...                       ...       ...
# 190     SRX717366    h2ak5ac_4  Saccharomyces_cerevisiae  ChIP-Seq
# 191     SRX717365    h2ak5ac_8  Saccharomyces_cerevisiae  ChIP-Seq
# 192     SRX717364   h2ak5ac_15  Saccharomyces_cerevisiae  ChIP-Seq
# 193     SRX717363   h2ak5ac_30  Saccharomyces_cerevisiae  ChIP-Seq
# 194     SRX717362   h2ak5ac_60  Saccharomyces_cerevisiae  ChIP-Seq
#
#                                             attributes
# 0    source_name : BY4741 stress : diamide time : 1...
# 1    source_name : BY4741 stress : diamide time : 1...
# 2    source_name : BY4741 stress : diamide time : 8...
# 3    source_name : BY4741 stress : diamide time : 8...
# 4    source_name : BY4741 stress : diamide time : 6...
# ..                                                 ...
# 190  source_name : BY4741 stress : diamide time : 4...
# 191  source_name : BY4741 stress : diamide time : 8...
# 192  source_name : BY4741 stress : diamide time : 1...
# 193  source_name : BY4741 stress : diamide time : 3...
# 194  source_name : BY4741 stress : diamide time : 6...
#
# [195 rows x 10 columns]

# %% [markdown]
# When we're happy with our subset of experiments we can then rerun `annotate()` with the subset metadata dataframe as input.\
# By default `annotate()` will save the annotation as a csv, but we can store the resulting dataframe to explore the results. \

# %%
#test = ptm_meta[ptm_meta['project_id'] == 'PRJNA262623']
ptm_meta_annotated = sragent.annotate(ptm_meta, 
                                      model_summary = 'gpt-4o-mini',
                                      model_annotation = 'gpt-4o-2024-08-06',
                                      annotate = True)
# Out:
# Let's break down the metadata and identify the key elements that will help classify and generate structured metadata for each experiment in the project.
#
# ### Main Goal of the Project
# The main goal of the project is to map 26 histone modifications genome-wide over a time course following dramatic transcriptional reprogramming in response to diamide stress in yeast. The project aims to understand the dynamics and combinatorial complexity of histone modifications during the stress response.
#
# ### Experimental Conditions
# - **Stress Condition**: Diamide stress
# - **Time Points**: 0, 4, 8, 15, 30, 60 minutes
# - **Controls**: MNase input controls at each time point
# - **Histone Modifications**: 26 different histone modifications
#
# ### Key Words and Their Indications
#
# #### Gene Mutations
# - **Key Words**: There are no specific keywords indicating gene mutations in the provided metadata. The strain used is BY4741, which is a common yeast strain and does not indicate any specific mutations relevant to the project goal.
#
# #### Gene Deletions
# - **Key Words**: There are no specific keywords indicating gene deletions in the provided metadata. The strain used is BY4741, which does not indicate any specific gene deletions relevant to the project goal.
#
# #### Protein Depletions
# - **Key Words**: There are no specific keywords indicating protein depletions in the provided metadata. The project does not mention any protein depletion experiments.
#
# #### Chemical Treatments or Stress Conditions
# - **Key Words**: "diamide" indicates the chemical treatment used to induce stress in the yeast cells. This signifies that the cells were subjected to oxidative stress.
#
# #### Time Points or Stages of Development/Growth
# - **Key Words**: "time" followed by a specific minute value (e.g., "0 min", "4 min", "8 min", "15 min", "30 min", "60 min") indicates the different time points at which samples were collected during the stress response.
#
# #### ChIP Input Control
# - **Key Words**: "input" in the experiment title indicates that the experiment is a ChIP Input control. For example, "input1.1_0" or "input2.2_15".
#
# #### Non-Specific Antibody Control
# - **Key Words**: There are no specific keywords indicating non-specific antibody controls in the provided metadata.
#
# #### ChIP-seq Protein Targets
# - **Key Words**: The experiment titles and attributes contain the specific histone modifications being targeted. For example:
#   - "h4r3me2s" indicates the histone modification H4R3me2s.
#   - "h4k8ac" indicates the histone modification H4K8ac.
#   - "h3k4me3" indicates the histone modification H3K4me3.
#   - If an experiment is identified as 'Input', the protein target must be 'None'.
#
# #### Experimental Replicates
# - **Key Words**: "experimental_batch" followed by a specific value (e.g., "1.1", "2.2", "3.1") indicates different experimental replicates.
#
# #### Small Molecules Used
# - **Key Words**: "diamide" is the small molecule used to induce stress in the yeast cells.
#
# ### Structured Metadata Elements
# Based on the identified key words, the structured metadata for each experiment should include the following elements:
# - **Experiment ID**
# - **Experiment Title**
# - **Source Name**: The yeast strain used (e.g., BY4741)
# - **Stress Condition**: The chemical treatment used (e.g., diamide)
# - **Time Point**: The time at which the sample was collected (e.g., 0 min, 4 min, 8 min, 15 min, 30 min, 60 min)
# - **Antibody**: The antibody used for ChIP-seq (e.g., anti-h4r3me2s, anti-h4k8ac)
# - **Experimental Batch**: The replicate batch (e.g., 1.1, 2.2, 3.1)
# - **ChIP-seq Protein Target**: The specific histone modification or 'None' for input controls (e.g., H4R3me2s, H4K8ac, None)
# - **Control Type**: Indicate if the experiment is an input control (e.g., Input Control, None)
#
# ### Example Structured Metadata for an Experiment
# Here is an example of structured metadata for one of the experiments:
#
# **Experiment ID**: SRX717562
# - **Experiment Title**: input2.2_15
# - **Source Name**: BY4741
# - **Stress Condition**: diamide
# - **Time Point**: 15 min
# - **Antibody**: na
# - **Experimental Batch**: 2.2
# - **ChIP-seq Protein Target**: None
# - **Control Type**: Input Control
#
# By following this approach, you can classify and generate structured metadata for each experiment in the project.
# annotating experiment 0    SRX717562
# Name: experiment_id, dtype: object...
# annotating experiment 1    SRX717561
# Name: experiment_id, dtype: object...
# annotating experiment 2    SRX717560
# Name: experiment_id, dtype: object...
# annotating experiment 3    SRX717559
# Name: experiment_id, dtype: object...
# annotating experiment 4    SRX717558
# Name: experiment_id, dtype: object...
# annotating experiment 5    SRX717557
# Name: experiment_id, dtype: object...
# annotating experiment 6    SRX717556
# Name: experiment_id, dtype: object...
# annotating experiment 7    SRX717555
# Name: experiment_id, dtype: object...
# annotating experiment 8    SRX717554
# Name: experiment_id, dtype: object...
# annotating experiment 9    SRX717553
# Name: experiment_id, dtype: object...
# annotating experiment 10    SRX717552
# Name: experiment_id, dtype: object...
# annotating experiment 11    SRX717551
# Name: experiment_id, dtype: object...
# annotating experiment 12    SRX717550
# Name: experiment_id, dtype: object...
# annotating experiment 13    SRX717549
# Name: experiment_id, dtype: object...
# annotating experiment 14    SRX717548
# Name: experiment_id, dtype: object...
# annotating experiment 15    SRX717547
# Name: experiment_id, dtype: object...
# annotating experiment 16    SRX717546
# Name: experiment_id, dtype: object...
# annotating experiment 17    SRX717545
# Name: experiment_id, dtype: object...
# annotating experiment 18    SRX717544
# Name: experiment_id, dtype: object...
# annotating experiment 19    SRX717543
# Name: experiment_id, dtype: object...
# annotating experiment 20    SRX717542
# Name: experiment_id, dtype: object...
# annotating experiment 21    SRX717541
# Name: experiment_id, dtype: object...
# annotating experiment 22    SRX717540
# Name: experiment_id, dtype: object...
# annotating experiment 23    SRX717539
# Name: experiment_id, dtype: object...
# annotating experiment 24    SRX717538
# Name: experiment_id, dtype: object...
# annotating experiment 25    SRX717537
# Name: experiment_id, dtype: object...
# annotating experiment 26    SRX717536
# Name: experiment_id, dtype: object...
# annotating experiment 27    SRX717535
# Name: experiment_id, dtype: object...
# annotating experiment 28    SRX717534
# Name: experiment_id, dtype: object...
# annotating experiment 29    SRX717533
# Name: experiment_id, dtype: object...
# annotating experiment 30    SRX717532
# Name: experiment_id, dtype: object...
# annotating experiment 31    SRX717531
# Name: experiment_id, dtype: object...
# annotating experiment 32    SRX717530
# Name: experiment_id, dtype: object...
# annotating experiment 33    SRX717529
# Name: experiment_id, dtype: object...
# annotating experiment 34    SRX717528
# Name: experiment_id, dtype: object...
# annotating experiment 35    SRX717527
# Name: experiment_id, dtype: object...
# annotating experiment 36    SRX717526
# Name: experiment_id, dtype: object...
# annotating experiment 37    SRX717525
# Name: experiment_id, dtype: object...
# annotating experiment 38    SRX717524
# Name: experiment_id, dtype: object...
# annotating experiment 39    SRX717523
# Name: experiment_id, dtype: object...
# annotating experiment 40    SRX717522
# Name: experiment_id, dtype: object...
# annotating experiment 41    SRX717521
# Name: experiment_id, dtype: object...
# annotating experiment 42    SRX717520
# Name: experiment_id, dtype: object...
# annotating experiment 43    SRX717519
# Name: experiment_id, dtype: object...
# annotating experiment 44    SRX717518
# Name: experiment_id, dtype: object...
# annotating experiment 45    SRX717511
# Name: experiment_id, dtype: object...
# annotating experiment 46    SRX717510
# Name: experiment_id, dtype: object...
# annotating experiment 47    SRX717509
# Name: experiment_id, dtype: object...
# annotating experiment 48    SRX717508
# Name: experiment_id, dtype: object...
# annotating experiment 49    SRX717507
# Name: experiment_id, dtype: object...
# annotating experiment 50    SRX717506
# Name: experiment_id, dtype: object...
# annotating experiment 51    SRX717505
# Name: experiment_id, dtype: object...
# annotating experiment 52    SRX717504
# Name: experiment_id, dtype: object...
# annotating experiment 53    SRX717503
# Name: experiment_id, dtype: object...
# annotating experiment 54    SRX717502
# Name: experiment_id, dtype: object...
# annotating experiment 55    SRX717501
# Name: experiment_id, dtype: object...
# annotating experiment 56    SRX717500
# Name: experiment_id, dtype: object...
# annotating experiment 57    SRX717499
# Name: experiment_id, dtype: object...
# annotating experiment 58    SRX717498
# Name: experiment_id, dtype: object...
# annotating experiment 59    SRX717497
# Name: experiment_id, dtype: object...
# annotating experiment 60    SRX717496
# Name: experiment_id, dtype: object...
# annotating experiment 61    SRX717495
# Name: experiment_id, dtype: object...
# annotating experiment 62    SRX717494
# Name: experiment_id, dtype: object...
# annotating experiment 63    SRX717493
# Name: experiment_id, dtype: object...
# annotating experiment 64    SRX717492
# Name: experiment_id, dtype: object...
# annotating experiment 65    SRX717491
# Name: experiment_id, dtype: object...
# annotating experiment 66    SRX717490
# Name: experiment_id, dtype: object...
# annotating experiment 67    SRX717489
# Name: experiment_id, dtype: object...
# annotating experiment 68    SRX717488
# Name: experiment_id, dtype: object...
# annotating experiment 69    SRX717487
# Name: experiment_id, dtype: object...
# annotating experiment 70    SRX717486
# Name: experiment_id, dtype: object...
# annotating experiment 71    SRX717485
# Name: experiment_id, dtype: object...
# annotating experiment 72    SRX717484
# Name: experiment_id, dtype: object...
# annotating experiment 73    SRX717483
# Name: experiment_id, dtype: object...
# annotating experiment 74    SRX717482
# Name: experiment_id, dtype: object...
# annotating experiment 75    SRX717481
# Name: experiment_id, dtype: object...
# annotating experiment 76    SRX717480
# Name: experiment_id, dtype: object...
# annotating experiment 77    SRX717479
# Name: experiment_id, dtype: object...
# annotating experiment 78    SRX717478
# Name: experiment_id, dtype: object...
# annotating experiment 79    SRX717477
# Name: experiment_id, dtype: object...
# annotating experiment 80    SRX717476
# Name: experiment_id, dtype: object...
# annotating experiment 81    SRX717475
# Name: experiment_id, dtype: object...
# annotating experiment 82    SRX717474
# Name: experiment_id, dtype: object...
# annotating experiment 83    SRX717473
# Name: experiment_id, dtype: object...
# annotating experiment 84    SRX717472
# Name: experiment_id, dtype: object...
# annotating experiment 85    SRX717471
# Name: experiment_id, dtype: object...
# annotating experiment 86    SRX717470
# Name: experiment_id, dtype: object...
# annotating experiment 87    SRX717469
# Name: experiment_id, dtype: object...
# annotating experiment 88    SRX717468
# Name: experiment_id, dtype: object...
# annotating experiment 89    SRX717467
# Name: experiment_id, dtype: object...
# annotating experiment 90    SRX717466
# Name: experiment_id, dtype: object...
# annotating experiment 91    SRX717465
# Name: experiment_id, dtype: object...
# annotating experiment 92    SRX717464
# Name: experiment_id, dtype: object...
# annotating experiment 93    SRX717463
# Name: experiment_id, dtype: object...
# annotating experiment 94    SRX717462
# Name: experiment_id, dtype: object...
# annotating experiment 95    SRX717461
# Name: experiment_id, dtype: object...
# annotating experiment 96    SRX717460
# Name: experiment_id, dtype: object...
# annotating experiment 97    SRX717459
# Name: experiment_id, dtype: object...
# annotating experiment 98    SRX717458
# Name: experiment_id, dtype: object...
# annotating experiment 99    SRX717457
# Name: experiment_id, dtype: object...
# annotating experiment 100    SRX717456
# Name: experiment_id, dtype: object...
# annotating experiment 101    SRX717455
# Name: experiment_id, dtype: object...
# annotating experiment 102    SRX717454
# Name: experiment_id, dtype: object...
# annotating experiment 103    SRX717453
# Name: experiment_id, dtype: object...
# annotating experiment 104    SRX717452
# Name: experiment_id, dtype: object...
# annotating experiment 105    SRX717451
# Name: experiment_id, dtype: object...
# annotating experiment 106    SRX717450
# Name: experiment_id, dtype: object...
# annotating experiment 107    SRX717449
# Name: experiment_id, dtype: object...
# annotating experiment 108    SRX717448
# Name: experiment_id, dtype: object...
# annotating experiment 109    SRX717447
# Name: experiment_id, dtype: object...
# annotating experiment 110    SRX717446
# Name: experiment_id, dtype: object...
# annotating experiment 111    SRX717445
# Name: experiment_id, dtype: object...
# annotating experiment 112    SRX717444
# Name: experiment_id, dtype: object...
# annotating experiment 113    SRX717443
# Name: experiment_id, dtype: object...
# annotating experiment 114    SRX717442
# Name: experiment_id, dtype: object...
# annotating experiment 115    SRX717441
# Name: experiment_id, dtype: object...
# annotating experiment 116    SRX717440
# Name: experiment_id, dtype: object...
# annotating experiment 117    SRX717439
# Name: experiment_id, dtype: object...
# annotating experiment 118    SRX717438
# Name: experiment_id, dtype: object...
# annotating experiment 119    SRX717437
# Name: experiment_id, dtype: object...
# annotating experiment 120    SRX717436
# Name: experiment_id, dtype: object...
# annotating experiment 121    SRX717435
# Name: experiment_id, dtype: object...
# annotating experiment 122    SRX717434
# Name: experiment_id, dtype: object...
# annotating experiment 123    SRX717433
# Name: experiment_id, dtype: object...
# annotating experiment 124    SRX717432
# Name: experiment_id, dtype: object...
# annotating experiment 125    SRX717431
# Name: experiment_id, dtype: object...
# annotating experiment 126    SRX717430
# Name: experiment_id, dtype: object...
# annotating experiment 127    SRX717429
# Name: experiment_id, dtype: object...
# annotating experiment 128    SRX717428
# Name: experiment_id, dtype: object...
# annotating experiment 129    SRX717427
# Name: experiment_id, dtype: object...
# annotating experiment 130    SRX717426
# Name: experiment_id, dtype: object...
# annotating experiment 131    SRX717425
# Name: experiment_id, dtype: object...
# annotating experiment 132    SRX717424
# Name: experiment_id, dtype: object...
# annotating experiment 133    SRX717423
# Name: experiment_id, dtype: object...
# annotating experiment 134    SRX717422
# Name: experiment_id, dtype: object...
# annotating experiment 135    SRX717421
# Name: experiment_id, dtype: object...
# annotating experiment 136    SRX717420
# Name: experiment_id, dtype: object...
# annotating experiment 137    SRX717419
# Name: experiment_id, dtype: object...
# annotating experiment 138    SRX717418
# Name: experiment_id, dtype: object...
# annotating experiment 139    SRX717417
# Name: experiment_id, dtype: object...
# annotating experiment 140    SRX717416
# Name: experiment_id, dtype: object...
# annotating experiment 141    SRX717415
# Name: experiment_id, dtype: object...
# annotating experiment 142    SRX717414
# Name: experiment_id, dtype: object...
# annotating experiment 143    SRX717413
# Name: experiment_id, dtype: object...
# annotating experiment 144    SRX717412
# Name: experiment_id, dtype: object...
# annotating experiment 145    SRX717411
# Name: experiment_id, dtype: object...
# annotating experiment 146    SRX717410
# Name: experiment_id, dtype: object...
# annotating experiment 147    SRX717409
# Name: experiment_id, dtype: object...
# annotating experiment 148    SRX717408
# Name: experiment_id, dtype: object...
# annotating experiment 149    SRX717407
# Name: experiment_id, dtype: object...
# annotating experiment 150    SRX717406
# Name: experiment_id, dtype: object...
# annotating experiment 151    SRX717405
# Name: experiment_id, dtype: object...
# annotating experiment 152    SRX717404
# Name: experiment_id, dtype: object...
# annotating experiment 153    SRX717403
# Name: experiment_id, dtype: object...
# annotating experiment 154    SRX717402
# Name: experiment_id, dtype: object...
# annotating experiment 155    SRX717401
# Name: experiment_id, dtype: object...
# annotating experiment 156    SRX717400
# Name: experiment_id, dtype: object...
# annotating experiment 157    SRX717399
# Name: experiment_id, dtype: object...
# annotating experiment 158    SRX717398
# Name: experiment_id, dtype: object...
# annotating experiment 159    SRX717397
# Name: experiment_id, dtype: object...
# annotating experiment 160    SRX717396
# Name: experiment_id, dtype: object...
# annotating experiment 161    SRX717395
# Name: experiment_id, dtype: object...
# annotating experiment 162    SRX717394
# Name: experiment_id, dtype: object...
# annotating experiment 163    SRX717393
# Name: experiment_id, dtype: object...
# annotating experiment 164    SRX717392
# Name: experiment_id, dtype: object...
# annotating experiment 165    SRX717391
# Name: experiment_id, dtype: object...
# annotating experiment 166    SRX717390
# Name: experiment_id, dtype: object...
# annotating experiment 167    SRX717389
# Name: experiment_id, dtype: object...
# annotating experiment 168    SRX717388
# Name: experiment_id, dtype: object...
# annotating experiment 169    SRX717387
# Name: experiment_id, dtype: object...
# annotating experiment 170    SRX717386
# Name: experiment_id, dtype: object...
# annotating experiment 171    SRX717385
# Name: experiment_id, dtype: object...
# annotating experiment 172    SRX717384
# Name: experiment_id, dtype: object...
# annotating experiment 173    SRX717383
# Name: experiment_id, dtype: object...
# annotating experiment 174    SRX717382
# Name: experiment_id, dtype: object...
# annotating experiment 175    SRX717381
# Name: experiment_id, dtype: object...
# annotating experiment 176    SRX717380
# Name: experiment_id, dtype: object...
# annotating experiment 177    SRX717379
# Name: experiment_id, dtype: object...
# annotating experiment 178    SRX717378
# Name: experiment_id, dtype: object...
# annotating experiment 179    SRX717377
# Name: experiment_id, dtype: object...
# annotating experiment 180    SRX717376
# Name: experiment_id, dtype: object...
# annotating experiment 181    SRX717375
# Name: experiment_id, dtype: object...
# annotating experiment 182    SRX717374
# Name: experiment_id, dtype: object...
# annotating experiment 183    SRX717373
# Name: experiment_id, dtype: object...
# annotating experiment 184    SRX717372
# Name: experiment_id, dtype: object...
# annotating experiment 185    SRX717371
# Name: experiment_id, dtype: object...
# annotating experiment 186    SRX717370
# Name: experiment_id, dtype: object...
# annotating experiment 187    SRX717369
# Name: experiment_id, dtype: object...
# annotating experiment 188    SRX717368
# Name: experiment_id, dtype: object...
# annotating experiment 189    SRX717367
# Name: experiment_id, dtype: object...
# annotating experiment 190    SRX717366
# Name: experiment_id, dtype: object...
# annotating experiment 191    SRX717365
# Name: experiment_id, dtype: object...
# annotating experiment 192    SRX717364
# Name: experiment_id, dtype: object...
# annotating experiment 193    SRX717363
# Name: experiment_id, dtype: object...
# annotating experiment 194    SRX717362
# Name: experiment_id, dtype: object...
# project PRJNA262623 done!
# tagging...
# setting controls...

# %% [markdown]
# For this large example, using `gpt-4o-mini` as of 08/13/24, annotation took 33m54s, using ~1.8M tokens (1.68M context, 0.1M generated) at a total cost of ~$0.30. \
# For the larger `gpt-4o` model (is currently ~35x more expensive) we can ballpark the same annotation would cost ~$10.5 \
# This is a rough estimate because input and output cost differs substantially, but gives a decent idea.

# %% [markdown]
# So what did `annotate()` do?
# Let's take a look at the output, which should be saved as `annotation_FULL.csv` in the `sragent_output` directory.

# %% [markdown]
# `ptm_meta_annotated` is a pandas dataframe with the following columns: \
# - `project_id`
# - `experiment_id`
# - `exp_title` - title of the experiment as listed in the SRA metadata
# (the following columns are generated from the LLM response)
# - `gene_mutatation` - True or False: does this experiment test a gene mutation?
# - `gene_deletion` - True or False: does this experiment test a gene deletion?
# - `protein_depletion` - True or False: does this experiment test a protein depletion?
# - `stress_condition` - True or False: does this experiment test a stress condition?
# - `time_series` - True or False: is this experiment specify a specific time point or growth stage?
# - `chip_input` - True or False: is this an input experiment?
# - `antibody_control` - True or False: is this an antibody control? ie. a non-specific antibody
# - `chip_target` - protein targeted in the experiment
# - `mutatation` - specific mutation if present
# - `deletion` - specific deletion if present
# - `depletion` - protein depleted if present
# - `stress` - stress condition if present
# - `time_point`
# (the following are determined based on the classifications from the LLM above)
# - `warnning` - True or False: flags a logical disagreement between the LLM classifications. Useful to catch mistakes and guide human review
# - `sample` - a simple sample name or tag that merges experiment attributes like genotype, time, target.
# - `perturbation` - one of ['None','gene_mutation','gene_deletion','protein_depletion','stress_condition']
# - `control` - the `sample` name of the control (input or other) experiment that matches target for that project

# %% [markdown]
# Let's examine how well the `gpt-4o-mini` model did at classifying and annotating these experiments.\
# How many experiments were flagged for review?

# %%
ptm_meta_annotated
#print(ptm_meta_annotated[ptm_meta_annotated['warning']])
# Out:
#               experiment_id    exp_title  gene_mutation  gene_deletion  \
# project_id
# PRJNA262623 0     SRX717474    h4k12ac_4          False          False
#             2     SRX717446   h3k79me_60          False          False
#             3     SRX717506  h4r3me2s_60          False          False
#             4     SRX717485    h4k20me_8          False          False
#             1     SRX717537  input1.2_60          False          False
#
#                protein_depletion  stress_condition  time_series  chip_input  \
# project_id
# PRJNA262623 0              False              True         True       False
#             2              False              True         True       False
#             3              False              True         True       False
#             4              False              True         True       False
#             1              False              True         True        True
#
#                antibody_control chip_target  ... deletion depletion   stress  \
# project_id                                   ...
# PRJNA262623 0             False     H4K12ac  ...                     diamide
#             2             False     H3K79me  ...                     diamide
#             3             False    H4R3me2s  ...                     diamide
#             4             False     H4K20me  ...                     diamide
#             1             False              ...                     diamide
#
#               time_point   project_id   model warning  \
# project_id
# PRJNA262623 0      4 min  PRJNA262623  gpt-4o   False
#             2     60 min  PRJNA262623  gpt-4o   False
#             3     60 min  PRJNA262623  gpt-4o   False
#             4      8 min  PRJNA262623  gpt-4o   False
#             1     60 min  PRJNA262623  gpt-4o   False
#
#                                                  sample      perturbation  \
# project_id
# PRJNA262623 0    H4K12ac-diamide-stress_condition-4_min  stress_condition
#             2   H3K79me-diamide-stress_condition-60_min  stress_condition
#             3  H4R3me2s-diamide-stress_condition-60_min  stress_condition
#             4    H4K20me-diamide-stress_condition-8_min  stress_condition
#             1     Input-diamide-stress_condition-60_min  stress_condition
#
#                                              control
# project_id
# PRJNA262623 0                                   None
#             2  Input-diamide-stress_condition-60_min
#             3  Input-diamide-stress_condition-60_min
#             4                                   None
#             1                                    NaN
#
# [5 rows x 21 columns]
